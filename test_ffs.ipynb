# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft, ifft
from ffs_alpha import FFS
import seaborn as sns

sns.set_style("whitegrid")

# %matplotlib inline

# %%
x = np.linspace(-2,2,50)
y_bell = np.exp(-x**2)
fs_bell = FFS(x,y_bell,0)

plt.figure(figsize=(15,10))
plt.plot(x,y_bell,'b',linewidth=10, alpha = 0.25, label = 'Input Function')
plt.plot(x,fs_bell.evaluate(x),'r', label = 'Fourier Series Approximation')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim((-0.1, 1.1))
plt.title('Fourier Series Representation of the Standard Normal Bell Curve - Wave Number = 25')
plt.legend()
plt.tight_layout()

# plt.savefig('images/bell_curve.png')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(x,y_bell,'b',linewidth=10, alpha = 0.25, label = 'Input Function')
plt.plot(x,fs_bell.evaluate(x, 2),'r', label = 'Fourier Series Approximation')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim((-0.1, 1.1))
plt.title('Fourier Series Representation of the Standard Normal Bell Curve - Wave Number = 2')
plt.legend()
plt.tight_layout()

# plt.savefig('images/bell_curve_1.png')
plt.show()

# %%
x = np.linspace(-2,2,50)
y_cubic = x**3
fs_cubic = FFS(x,y_cubic,0)

plt.figure(figsize=(15,10))
plt.plot(x,y_cubic,'b',linewidth=10, alpha = 0.25, label = 'Input Function')
plt.plot(x,fs_cubic.evaluate(x),'r', label = 'Fourier Series Approximation')
plt.xlabel('x')
plt.ylabel('y')
# plt.ylim((-0.1, 1.1))
plt.title('Fourier Series Representation of the Standard Cubic Function - Wave Number = 25')
plt.legend(loc = 'upper left')
plt.tight_layout()

# plt.savefig('images/cubic.png')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.plot(x,y_cubic,'b',linewidth=10, alpha = 0.25, label = 'Input Function')
plt.plot(x,fs_cubic.evaluate(x,10),'r', label = 'Fourier Series Approximation')
plt.xlabel('x')
plt.ylabel('y')
# plt.ylim((-0.1, 1.1))
plt.title('Fourier Series Representation of the Standard Cubic Function - Wave Number = 10')
plt.legend(loc = 'upper left')
plt.tight_layout()

# plt.savefig('images/cubic_10.png')
plt.show()

# %%
x = np.linspace(-2,2,50)
y_cubic = x**3
fs_cubic = FFS(x,y_cubic,0)

plt.figure(figsize=(15,10))
plt.plot(x,y_cubic,'b',linewidth=10, alpha = 0.25, label = 'Input Function')
plt.plot(x,fs_cubic.evaluate(x),'r', label = 'Fourier Series: Wave Number = 25')
plt.plot(x,fs_cubic.evaluate(x,10),'g', label = 'Fourier Series: Wave Number = 10')
plt.xlabel('x')
plt.ylabel('y')
# plt.ylim((-0.1, 1.1))
plt.title('Fourier Series Representation of the Standard Cubic Function')
plt.legend(loc = 'upper left')
plt.tight_layout()

# plt.savefig('images/cubic.png')
plt.show()

# %%
x = np.linspace(-2,2,50)
y_cubic = x**3
fs_cubic = FFS(x,y_cubic,50)

plt.figure(figsize=(15,10))
plt.plot(x,y_cubic,'b',linewidth=10, alpha = 0.25, label = 'Input Function')
plt.plot(x,fs_cubic.evaluate(x),'r', label = 'Fourier Series Approximation')
plt.xlabel('x')
plt.ylabel('y')
# plt.ylim((-0.1, 1.1))
plt.title('Padded Fourier Series Representation of the Standard Cubic Function - Wave Number = 25')
plt.legend(loc = 'upper left')
plt.tight_layout()

# plt.savefig('images/cubic_padded.png')
plt.show()

# %%
wave_number = 3

plt.figure(figsize=(15,10))
plt.plot(x,y_cubic,'b',linewidth=10, alpha = 0.25, label = 'Input Function')
plt.plot(x,fs_cubic.evaluate(x,wave_number),'r', label = 'Fourier Series Approximation')
plt.xlabel('x')
plt.ylabel('y')
# plt.ylim((-0.1, 1.1))
plt.title('Padded Fourier Series Representation of the Standard Cubic Function - Wave Number = {0}'.format(wave_number))
plt.legend(loc = 'upper left')
plt.tight_layout()

# plt.savefig('images/cubic_10_padded.png')
plt.show()

# %%
x = np.linspace(-2,2,50)
y_cubic = x**3
fs_cubic = FFS(x,y_cubic,0)

xx = np.linspace(-2,6,100)

plt.figure(figsize=(15,10))
plt.plot(x,y_cubic,'b',linewidth=10, alpha = 0.25, label = 'Input Function')
plt.plot(xx,fs_cubic.evaluate(xx),'r', label = 'Fourier Series Approximation')
plt.xlabel('x')
plt.ylabel('y')
# plt.ylim((-0.1, 1.1))
plt.title('Fourier Series Representation of the Standard Cubic Function - Wave Number = 25')
plt.legend(loc = 'upper left')
plt.tight_layout()

plt.show()

# %%
x = np.linspace(-2,2,50)
y_cubic = x**3
fs_cubic = FFS(x,y_cubic,50)

xa = fs_cubic.xa
xb = fs_cubic.xb

xx = np.linspace(xa, xa + 2*(xb-xa), 200)

plt.figure(figsize=(15,10))
# plt.plot(x,y_cubic,'b',linewidth=10, alpha = 0.25, label = 'Input Function')
# plt.plot(xx,fs_cubic.evaluate(xx),'r', label = 'Fourier Series Approximation')

plt.xlabel('x')
plt.ylabel('y')
# plt.ylim((-0.1, 1.1))
plt.title('Padded Fourier Series Representation of the Standard Cubic Function - Wave Number = 25')
plt.legend(loc = 'upper left')
plt.tight_layout()

plt.show()
# Out:
# /home/jbhersch/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
x1 = np.linspace(0,1,5)
x2 = np.linspace(1,2,5)
np.hstack((x1,1.25))
# Out:
# array([ 0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25])

# %%
x = np.linspace(-2,2,50)
y_bell = np.exp(-x**2)
fs_bell = FFS(x,y_bell,0)

xx = np.hstack((x, fs_bell.xb+fs_bell.h))

plt.figure(figsize=(15,10))
plt.plot(x,y_bell,'b',linewidth=10, alpha = 0.25, label = 'Input Function')
plt.plot(xx,fs_bell.evaluate(xx),'r', label = 'Fourier Series Approximation')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim((-0.1, 1.1))
plt.title('Fourier Series Representation of the Standard Normal Bell Curve - Wave Number = 25')
plt.legend()
plt.tight_layout()

plt.show()

# print x[-1]
# print fs_bell.xb
# print fs_bell.xa + fs_bell.L

# %%
x = np.linspace(-2,2,50)
y_cubic = x**3
fs_cubic = FFS(x,y_cubic,0)

xx = np.hstack((x, fs_cubic.xb+fs_cubic.h))

plt.figure(figsize=(15,10))
plt.plot(xx,fs_cubic.evaluate(xx),'b', label="First Period")
plt.plot(xx + fs_cubic.L,fs_cubic.evaluate(xx + fs_cubic.L),'r', label="Second Period")
plt.title("Periodic Nature of Fourier Series")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc = 'upper left')
plt.tight_layout()

plt.show()

# %%
num_points = 50

x = np.linspace(-2,2,num_points)
noise = np.random.uniform(low = -0.1, high = 0.1, size=num_points)
y = np.exp(-x**2)

y_ = fft(y+noise)
y_abs = np.absolute(y_)

plt.figure(figsize=(15,10))
# plt.plot(x,y,'b')
# plt.plot(x,y+noise,'r')
plt.plot(y_abs[1:], 'b-o')

plt.tight_layout()
plt.show()

print np.median(y_abs[1:])/2
# Out:
# 0.211308022338

# %%
x = np.random.uniform(size=10)
indices = np.where(x>0.5)[0]
print x
x[indices] = 0
print np.hstack((1,x))
# Out:
# [ 0.58755878  0.35601297  0.27607433  0.29853988  0.76819744  0.44761675
#   0.98356411  0.48948238  0.71364213  0.1106525 ]
# [ 1.          0.          0.35601297  0.27607433  0.29853988  0.
#   0.44761675  0.          0.48948238  0.          0.1106525 ]

# %%
def remove_noise(y, thresh):
    yt = fft(y)
    yt0 = yt[0]
    yt = yt[1:]
    yt_abs = np.absolute(yt)
    yt_max = np.max(yt_abs)
    indices = np.where(yt_abs < thresh*yt_max)[0]
    yt[indices] = np.complex(0,0)
    return ifft(np.hstack((yt0, yt)))

# %%
num_points = 300

xa = -2
xb = 2
L = xb - xa

x = np.linspace(xa,xb,num_points)
y = np.exp(-x**2)
omega = 2*np.pi/L
wave_number = 20
amplitude = 0.5
noise = amplitude*np.sin(wave_number*omega*(x-xa))
y_noise = y + noise

yt = fft(y_noise)
# yt = 2*np.absolute(yt[1:len(yt)/2])/(len(y)-1)
yt = 2*np.absolute(yt[1:len(yt)/2])/(len(y))

plt.figure(figsize=(15,10))

plt.subplot(2,1,1)
plt.plot(x, y,'b',label="True Signal")
plt.plot(x, y_noise,'r',label="Noisy Signal")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Signal In x-y Space")
plt.legend()

plt.subplot(2,1,2)
plt.stem(range(1,51), np.abs(yt[:50]))
plt.xticks(range(1,51))
plt.xlabel("Harmonic Wave Number")
plt.ylabel("Wave Amplitude")
plt.title("Wave Representation of Signal")

plt.tight_layout()
plt.show()

# %%
num_points = 100

x = np.linspace(-2,2,num_points)
amplitude = 0.2
noise = amplitude*np.random.uniform(low = -1, high = 1, size=num_points)
y = np.exp(-x**2)
y_noise = y + noise

thresh = 0.125
fs = FFS(x,y_noise,thresh = thresh)

yt = fft(y_noise)
yt = 2*np.absolute(yt[1:len(yt)/2])/(len(y)-1)

plt.figure(figsize=(15,10))

plt.subplot(2,1,1)
plt.plot(x, y,'b',label="True Signal")
plt.plot(x, y_noise,'r',label="Noisy Signal")
plt.plot(x, fs.y, 'g', label="Signal With Noise Removal")
plt.legend()

plt.subplot(2,1,2)
plt.stem(range(1,len(yt)+1), np.abs(yt))
plt.xticks(range(1,len(yt)+1))
plt.xlabel("Harmonic Wave Number")
plt.ylabel("Wave Amplitude")
plt.title("Signal In Complex Space")
plt.axhline(y=thresh*np.max(yt), color='r', linestyle='-',label="Cutoff Threshold")
plt.legend()

plt.tight_layout()
plt.show()

# %%
x = np.array([1,3,2,3])
print x
print x[::-1]
# Out:
# [1 3 2 3]
# [3 2 3 1]

# %%
y = np.array([1,2,3,4,5])
yt = fft(y)
print yt
# Out:
# [ 15.0+0.j          -2.5+3.4409548j   -2.5+0.81229924j  -2.5-0.81229924j
#   -2.5-3.4409548j ]
